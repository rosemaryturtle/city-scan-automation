# %%
import pandas as pd
import geopandas as gpd
from pathlib import Path
import os
os.chdir("/Users/danielcp/Documents/2023_WORLD_BANK/21_CRP/12_New_Structure/city-scan-automation")

# %%
import sys

# Add project root folder
sys.path.append("/Users/danielcp/Documents/2023_WORLD_BANK/21_CRP/12_New_Structure/city-scan-automation")

# Import function
from tasks.population_worldpop.datacollection import datacollection

# Run
datacollection(
    aoi_path="inputs/AOI/South_Jakarta-Jakarta.shp",
    output_dir="output/worldpop"
)
# Out:
# 2025-12-08 13:45:04,073 | INFO | tasks.population_worldpop.datacollection | datacollection.py:27 | Starting WorldPop data collection…
# 2025-12-08 13:45:04,075 | INFO | tasks.population_worldpop.datacollection | datacollection.py:33 | loading AOI from: inputs/AOI/South_Jakarta-Jakarta.shp
# /Users/danielcp/Documents/2023_WORLD_BANK/21_CRP/12_New_Structure/city-scan-automation/tasks/population_worldpop/datacollection.py:41: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['area'] = intersection.geometry.area
# 2025-12-08 13:45:18,792 | INFO | tasks.population_worldpop.datacollection | datacollection.py:46 | detect ISO3 from AOI: idn
# 2025-12-08 13:45:18,793 | INFO | tasks.population_worldpop.datacollection | datacollection.py:53 | Requesting WorldPop raster: https://storage.googleapis.com/city-scan-global-public/WorldPop/idn_ppp_2020_constrained.tif
# 2025-12-08 13:45:21,437 | INFO | tasks.population_worldpop.datacollection | datacollection.py:57 | WorldPop raster opened successfully.
# 2025-12-08 13:45:24,661 | INFO | tasks.population_worldpop.datacollection | datacollection.py:87 | Clipped WorldPop saved to: output/worldpop/idn_worldpop_clipped.tif
# 2025-12-08 13:45:24,662 | INFO | tasks.population_worldpop.datacollection | datacollection.py:91 | WorldPop clipping complete.
